# %% [markdown]
# <a href="https://colab.research.google.com/github/batuhancevirgen/flower_/blob/main/fine_tune_whisper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/openai/whisper.git -q -U
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
# !pip install yt-dlp -q -U
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.0/180.0 kB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 67.7 MB/s eta 0:00:00

# %%
# !yt-dlp "https://youtu.be/V48PsPadnRc" --format m4a -o "/content/%(id)s.%(ext)s"
# !whisper "/content/V48PsPadnRc.m4a" --model small --language Turkish
# Out:
# [youtube] Extracting URL: https://youtu.be/V48PsPadnRc
# [youtube] V48PsPadnRc: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one. To silence this warning, you can use  --extractor-args "youtube:player_client=default"
# [youtube] V48PsPadnRc: Downloading android sdkless player API JSON
# [youtube] V48PsPadnRc: Downloading web safari player API JSON
# WARNING: [youtube] V48PsPadnRc: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# [youtube] V48PsPadnRc: Downloading m3u8 information
# ...
